# %%
import json

# %%
with open('parsed_data.json') as json_file:
    dta = json.load(json_file)

# %%
dta
# Out:
# {'Victoria Pittard': {'word_counts': {'Awesome,': 1,
#    'if': 3,
#    'you': 8,
#    'let': 1,
#    'me': 1,
#    'know': 1,
#    'when': 3,
#    'youâ\x80\x99re': 1,
#    'back': 4,
#    'Iâ\x80\x99ll': 2,
#    'swing': 2,
#    'by': 2,
#    'Hey': 3,
#    'can': 2,
#    'I': 2,
#    'and': 9,
#    'pick': 1,
#    'up': 3,
#    'the': 8,
#    'speaker': 3,
#    'at': 5,
#    'some': 3,
#    'point': 1,
#    'tonight?': 1,
#    'i': 10,
#    'know,': 1,
#    'just': 5,
#    'wanted': 4,
#    'to': 9,
#    'give': 2,
#    'a': 2,
#    'heads': 2,
#    'in': 8,
#    'case': 3,
#    "didn't": 2,
#    'hear': 1,
#    'ab': 1,
#    'it': 9,
#    'idk': 1,
#    'they': 2,
#    'came': 1,
#    'talk': 1,
#    'but': 3,
#    'anything': 3,
#    'happened': 2,
#    'with': 1,
#    "y'all": 1,
#    'someone': 2,
#    'from': 3,
#    '5016': 1,
#    'knocked': 1,
#    'on': 2,
#    'our': 1,
#    'door': 1,
#    'asked': 1,
#    'we': 2,
#    'heard': 2,
#    '9:30-11:30': 1,
#    'bc': 1,
# ...
